# %%
# Notebook Setup
# Run this cell: 
# The lines below will instruct jupyter to reload imported modules before 
# executing code cells. This enables you to quickly iterate and test revisions
# to your code without having to restart the kernel and reload all of your 
# modules each time you make a code change in a separate python file.

# %load_ext autoreload
# %autoreload 2

import os

# Change path to project root
if os.getcwd().endswith("notebooks"):
    os.chdir(os.path.dirname(os.getcwd()))
print(os.getcwd())
# Out:
# /Users/shloknatarajan/stanford/research/daneshjou/clinpgx-lookup

# %%
from src.clinpgx_lookup.variant_search import VariantLookup

# %%
variant_lookup = VariantLookup()

# %%
variant_lookup.search("UGT1A9*2")
# Out:
# [VariantSearchResult(raw_input='UGT1A9*2', id='PA166117679', name='UGT1A9*2', url='https://www.clinpgx.org/haplotype/PA166117679', score=1.0)]

# %%
variant_lookup.search("UGT1A9*22")
# Out:
# [VariantSearchResult(raw_input='UGT1A9*22', id='PA166155718', name='rs3832043', url='https://www.clinpgx.org/variant/PA166155718', score=1.0)]
